# %%
import pandas as pd

# %%
df = pd.read_csv("NLP_Engineer/data/processed/listing_sample.csv")
df.head()
# Out:
#    L_ListingID                  L_Address         L_City  beds  baths  \
# 0   1169503734         133 Crystal Street           Taft   3.0    2.0
# 1   1154220129               15664 Kadota    Victorville   4.0    4.0
# 2   1159921951  949 S Manhattan Place 203    Los Angeles   3.0    2.0
# 3   1170333192    1872 Seascape Boulevard          Aptos   3.0    3.0
# 4   1152463169     2085 Westhampton Drive  Arroyo Grande   3.0    2.0
#
#      price                                            remarks
# 0   235000  This unique property offers two homes on one l...
# 1   459000  Beautiful Two-Story Home in Victorville – Spac...
# 2   689000  Presenting this exquisite second-floor corner ...
# 3  1195000  Thoughtfully renovated coastal retreat tucked ...
# 4  1050000  Welcome to 2085 Westhampton Drive in Arroyo Gr...
